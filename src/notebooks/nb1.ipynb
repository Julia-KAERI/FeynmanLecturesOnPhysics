# %%
using CairoMakie

# %%
me = 9.109e-31          # electron mass in kg
c = 299_792_458         # speed of light in m/sec
J2eV = 6.242e+18        # 1 J = 6.242e+18 eV
mu = 1.66039e-27        # atomic mass unit in kg
mpi = me*273            # pi-meson mass
# Out:
# 2.4867569999999997e-28

# %%
(273^2-207^2)/(2*273)*me*c^2*J2eV
# Out:
# 2.9650252932017453e7

# %%
T_p = 2*mpi * c* c*J2eV
γ = sqrt(T_p + 2 * mu * c^2 * J2eV)/sqrt(2*mu*c^2*J2eV)
T_pi = (γ -1)*mpi*c^2*J2eV
# Out:
# 1.008265215131912e7

# %%
1/(1.0-v)
# Out:
# 7.658755810119976e6

# %%
γ = 1.0e10/0.938
v = sqrt(1-1/γ^2)
# Out:
# 1.0

# %%
L=c*1.0e5*3600*24*365
# Out:
# 9.454254955488e20

# %%
1.0e5/γ*3600*24*365
# Out:
# 295.80767999999995

# %%
# Out:
# 0.0:0.02:1.9

# %%
t=0:0.02:1.8
y = @. sin(t)*(1 / (t + 0.2) - 0.5)
f = Figure()
# Create an axis with a 1:1 aspect ratio
ax = Axis(f[1, 1], aspect = DataAspect())
lines!(t, y)
f

# %%
atan(0.3, 0.5)*180/pi
# Out:
# 30.96375653207352
